# %% [markdown]
# # HW3 — Linear Regression
# Name: Alice Chen

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Part 1: Load the data
# We read the CSV and inspect the shape.

# %%
df = pd.read_csv('housing.csv')
print(df.shape)
# Out:
# (506, 14)

# %% [markdown]
# ## Part 2: Fit the model

# %%
def fit(X, y):
    """Closed-form OLS."""
    return np.linalg.pinv(X.T @ X) @ X.T @ y

w = fit(X, y)
print('R2 =', r2)
# Out:
# R2 = 0.7406

# %%
plt.scatter(y, y_hat)
plt.show()

# %% [markdown]
# ## Conclusion
# The model explains ~74% of variance.
